# %%
import tensorflow as tf
from tensorflow.contrib import rnn
import numpy as np
import random

# %%
def shuffle(X, Y):
    indices = np.arange(X.shape[0])
    random.shuffle(indices)
    X = X[indices]
    Y = Y[indices]
    return X, Y

# %%
class Data:
    def __init__(self, featureDir='./rcnn/features/', 
                 labelDir='./timeseries_data/train_data/reshaped/', num_examples=400):
        sequences = []
        for i in range(num_examples):
            for j in range(200):
                sequence = []
                for k in range(10):
                    features = np.load(featureDir + 'features' + str(i) + '-' + str(j) + '-' + str(k) + '.npy')
                    sequence.append(features)
                sequences.append(sequence)
        x = np.array(sequences)
        
        label_list = []
        for i in range(num_examples):
            for _ in range(10):
                label_list.append(labelDir + 'drain_rate' + str(i) + '.npy')
        y = np.array([])
        for l in label_list:
            y = np.concatenate((y, np.load(l)))
        y = np.reshape(y, (y.shape[0], 1))
        self.x, self.y = x, y
        
    def next_batch(self, batch_size):
        self.x, self.y = shuffle(self.x, self.y)
        for i in range(0, self.x.shape[0], batch_size):
#             yield self.x[i], self.y[i]
            yield self.x[i:i+batch_size], self.y[i:i+batch_size]
    
    def next_batch_no_shuffle(self, batch_size):
        for i in range(0, self.x.shape[0], batch_size):
#             yield self.x[i], self.y[i]
            yield self.x[i:i+batch_size], self.y[i:i+batch_size]

# %%
# Parameters
learning_rate = 0.001
training_iters = 1000000
batch_size = 2000
display_step = 100

# Network Parameters
n_input = 1024 # MNIST data input (img shape: 28*28)
n_steps = 10 # timesteps
n_hidden = 128 # hidden layer num of features
n_classes = 1

# tf Graph input
x = tf.placeholder("float", [None, n_steps, n_input], name='x_input')
y = tf.placeholder("float", [None, n_classes], name='y_output')

# Define weights
rnn_weights = {
    'w_out': tf.Variable(tf.random_normal([n_hidden, n_classes]))
}
rnn_biases = {
    'b_out': tf.Variable(tf.random_normal([n_classes]))
}


def RNN(x, weights, biases):

    # Prepare data shape to match `rnn` function requirements
    # Current data input shape: (batch_size, n_steps, n_input)
    # Required shape: 'n_steps' tensors list of shape (batch_size, n_input)

    # Unstack to get a list of 'n_steps' tensors of shape (batch_size, n_input)
    x = tf.unstack(x, n_steps, 1)

    # Define a lstm cell with tensorflow
    lstm_cell = rnn.BasicLSTMCell(n_hidden, forget_bias=1.0)

    # Get lstm cell output
    outputs, states = rnn.static_rnn(lstm_cell, x, dtype=tf.float32)

    # Linear activation, using rnn inner loop last output
    return tf.matmul(outputs[-1], rnn_weights['w_out']) + rnn_biases['b_out']

pred = RNN(x, rnn_weights, rnn_biases)

# Define loss and optimizer
cost = tf.reduce_mean(tf.square(tf.subtract(pred, y)))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Initializing the variables
init = tf.global_variables_initializer()

combined = {}
combined.update(rnn_weights)
combined.update(rnn_biases)
saver = tf.train.Saver(combined)

# %%
# Launch the graph
with tf.Session() as sess:
    print("Initialized session")
    data = Data()
    newbatch = data.next_batch(batch_size)
    sess.run(init)

    print("Initialized run")
    
    step = 0
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        print("Starting iteration number: {0}".format(step * batch_size))
        
        try:
            batch_x, batch_y = next(newbatch)
        except StopIteration:
            newbatch = data.next_batch(batch_size)
            batch_x, batch_y = next(newbatch)
        
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y})
        
        if step % display_step == 0:
            print("Predictions: ", sess.run(pred, feed_dict={x: batch_x}))
            print("Actual: ", batch_y)
            loss = sess.run(cost, feed_dict={x: batch_x, y: batch_y})
            print("Minibatch Loss={:.6f}".format(loss))
        
        step += 1
               
    print("Done training!")
# Out:
# Initialized session
# Initialized run
# Starting iteration number: 0
# Predictions:  [[ 3.35484362]
#  [ 3.14675713]
#  [ 3.33685541]
#  ...,
#  [ 3.42544031]
#  [ 3.66080332]
#  [ 3.22477818]]
# Actual:  [[ 0.0545402 ]
#  [ 0.27647335]
#  [ 0.08924877]
#  ...,
#  [ 0.15733032]
#  [ 0.12809977]
#  [ 0.42273628]]
# Minibatch Loss=9.963923
# Starting iteration number: 2000
# Starting iteration number: 4000
# Starting iteration number: 6000
# Starting iteration number: 8000
# Starting iteration number: 10000
# Starting iteration number: 12000
# Starting iteration number: 14000
# Starting iteration number: 16000
# Starting iteration number: 18000
# Starting iteration number: 20000
# Starting iteration number: 22000
# Starting iteration number: 24000
# Starting iteration number: 26000
# Starting iteration number: 28000
# Starting iteration number: 30000
# Starting iteration number: 32000
# Starting iteration number: 34000
# Starting iteration number: 36000
# Starting iteration number: 38000
# Starting iteration number: 40000
# Starting iteration number: 42000
# Starting iteration number: 44000
# Starting iteration number: 46000
# Starting iteration number: 48000
# Starting iteration number: 50000
# Starting iteration number: 52000
# Starting iteration number: 54000
# Starting iteration number: 56000
# Starting iteration number: 58000
# Starting iteration number: 60000
# Starting iteration number: 62000
# Starting iteration number: 64000
# Starting iteration number: 66000
# Starting iteration number: 68000
# Starting iteration number: 70000
# Starting iteration number: 72000
# Starting iteration number: 74000
# Starting iteration number: 76000
# Starting iteration number: 78000
# Starting iteration number: 80000
# Starting iteration number: 82000
# Starting iteration number: 84000
# Starting iteration number: 86000
# Starting iteration number: 88000
# Starting iteration number: 90000
# Starting iteration number: 92000
# Starting iteration number: 94000
# Starting iteration number: 96000
# Starting iteration number: 98000
# Starting iteration number: 100000
# Starting iteration number: 102000
# Starting iteration number: 104000
# Starting iteration number: 106000
# Starting iteration number: 108000
# Starting iteration number: 110000
# Starting iteration number: 112000
# Starting iteration number: 114000
# Starting iteration number: 116000
# Starting iteration number: 118000
# Starting iteration number: 120000
# Starting iteration number: 122000
# Starting iteration number: 124000
# Starting iteration number: 126000
# Starting iteration number: 128000
# Starting iteration number: 130000
# Starting iteration number: 132000
# Starting iteration number: 134000
# Starting iteration number: 136000
# Starting iteration number: 138000
# Starting iteration number: 140000
# Starting iteration number: 142000
# Starting iteration number: 144000
# Starting iteration number: 146000
# Starting iteration number: 148000
# Starting iteration number: 150000
# Starting iteration number: 152000
# Starting iteration number: 154000
# Starting iteration number: 156000
# Starting iteration number: 158000
# Starting iteration number: 160000
# Starting iteration number: 162000
# Starting iteration number: 164000
# Starting iteration number: 166000
# Starting iteration number: 168000
# Starting iteration number: 170000
# Starting iteration number: 172000
# Starting iteration number: 174000
# Starting iteration number: 176000
# Starting iteration number: 178000
# Starting iteration number: 180000
# Starting iteration number: 182000
# Starting iteration number: 184000
# Starting iteration number: 186000
# Starting iteration number: 188000
# Starting iteration number: 190000
# Starting iteration number: 192000
# Starting iteration number: 194000
# Starting iteration number: 196000
# Starting iteration number: 198000
# Starting iteration number: 200000
# Predictions:  [[ 0.25063014]
#  [ 0.22114801]
#  [ 0.13679433]
#  ...,
#  [ 0.06599545]
#  [ 0.23958993]
#  [ 0.26279664]]
# Actual:  [[ 0.32732204]
#  [ 0.02731894]
#  [ 0.01558465]
#  ...,
#  [ 0.08186661]
#  [ 0.26767764]
#  [ 0.19891064]]
# Minibatch Loss=0.032420
# Starting iteration number: 202000
# Starting iteration number: 204000
# Starting iteration number: 206000
# Starting iteration number: 208000
# Starting iteration number: 210000
# Starting iteration number: 212000
# Starting iteration number: 214000
# Starting iteration number: 216000
# Starting iteration number: 218000
# Starting iteration number: 220000
# Starting iteration number: 222000
# Starting iteration number: 224000
# Starting iteration number: 226000
# Starting iteration number: 228000
# Starting iteration number: 230000
# Starting iteration number: 232000
# Starting iteration number: 234000
# Starting iteration number: 236000
# Starting iteration number: 238000
# Starting iteration number: 240000
# Starting iteration number: 242000
# Starting iteration number: 244000
# Starting iteration number: 246000
# Starting iteration number: 248000
# Starting iteration number: 250000
# Starting iteration number: 252000
# Starting iteration number: 254000
# Starting iteration number: 256000
# Starting iteration number: 258000
# Starting iteration number: 260000
# Starting iteration number: 262000
# Starting iteration number: 264000
# Starting iteration number: 266000
# Starting iteration number: 268000
# Starting iteration number: 270000
# Starting iteration number: 272000
# Starting iteration number: 274000
# Starting iteration number: 276000
# Starting iteration number: 278000
# Starting iteration number: 280000
# Starting iteration number: 282000
# Starting iteration number: 284000
# Starting iteration number: 286000
# Starting iteration number: 288000
# Starting iteration number: 290000
# Starting iteration number: 292000
# Starting iteration number: 294000
# Starting iteration number: 296000
# Starting iteration number: 298000
# Starting iteration number: 300000
# Starting iteration number: 302000
# Starting iteration number: 304000
# Starting iteration number: 306000
# Starting iteration number: 308000
# Starting iteration number: 310000
# Starting iteration number: 312000
# Starting iteration number: 314000
# Starting iteration number: 316000
# Starting iteration number: 318000
# Starting iteration number: 320000
# Starting iteration number: 322000
# Starting iteration number: 324000
# Starting iteration number: 326000
# Starting iteration number: 328000
# Starting iteration number: 330000
# Starting iteration number: 332000
# Starting iteration number: 334000
# Starting iteration number: 336000
# Starting iteration number: 338000
# Starting iteration number: 340000
# Starting iteration number: 342000
# Starting iteration number: 344000
# Starting iteration number: 346000
# Starting iteration number: 348000
# Starting iteration number: 350000
# Starting iteration number: 352000
# Starting iteration number: 354000
# Starting iteration number: 356000
# Starting iteration number: 358000
# Starting iteration number: 360000
# Starting iteration number: 362000
# Starting iteration number: 364000
# Starting iteration number: 366000
# Starting iteration number: 368000
# Starting iteration number: 370000
# Starting iteration number: 372000
# Starting iteration number: 374000
# Starting iteration number: 376000
# Starting iteration number: 378000
# Starting iteration number: 380000
# Starting iteration number: 382000
# Starting iteration number: 384000
# Starting iteration number: 386000
# Starting iteration number: 388000
# Starting iteration number: 390000
# Starting iteration number: 392000
# Starting iteration number: 394000
# Starting iteration number: 396000
# Starting iteration number: 398000
# Starting iteration number: 400000
# Predictions:  [[ 0.32953191]
#  [ 0.25262284]
#  [ 0.26979232]
#  ...,
#  [ 0.10918927]
#  [ 0.19605613]
#  [ 0.16146827]]
# Actual:  [[ 0.23308918]
#  [ 0.19084051]
#  [ 0.27919931]
#  ...,
#  [ 0.12220275]
#  [ 0.31703278]
#  [ 0.14675244]]
# Minibatch Loss=0.029915
# Starting iteration number: 402000
# Starting iteration number: 404000
# Starting iteration number: 406000
# Starting iteration number: 408000
# Starting iteration number: 410000
# Starting iteration number: 412000
# Starting iteration number: 414000
# Starting iteration number: 416000
# Starting iteration number: 418000
# Starting iteration number: 420000
# Starting iteration number: 422000
# Starting iteration number: 424000
# Starting iteration number: 426000
# Starting iteration number: 428000
# Starting iteration number: 430000
# Starting iteration number: 432000
# Starting iteration number: 434000
# Starting iteration number: 436000
# Starting iteration number: 438000
# Starting iteration number: 440000
# Starting iteration number: 442000
# Starting iteration number: 444000
# Starting iteration number: 446000
# Starting iteration number: 448000
# Starting iteration number: 450000
# Starting iteration number: 452000
# Starting iteration number: 454000
# Starting iteration number: 456000
# Starting iteration number: 458000
# Starting iteration number: 460000
# Starting iteration number: 462000
# Starting iteration number: 464000
# Starting iteration number: 466000
# Starting iteration number: 468000
# Starting iteration number: 470000
# Starting iteration number: 472000
# Starting iteration number: 474000
# Starting iteration number: 476000
# Starting iteration number: 478000
# Starting iteration number: 480000
# Starting iteration number: 482000
# Starting iteration number: 484000
# Starting iteration number: 486000
# Starting iteration number: 488000
# Starting iteration number: 490000
# Starting iteration number: 492000
# Starting iteration number: 494000
# Starting iteration number: 496000
# Starting iteration number: 498000
# Starting iteration number: 500000
# Starting iteration number: 502000
# Starting iteration number: 504000
# Starting iteration number: 506000
# Starting iteration number: 508000
# Starting iteration number: 510000
# Starting iteration number: 512000
# Starting iteration number: 514000
# Starting iteration number: 516000
# Starting iteration number: 518000
# Starting iteration number: 520000
# Starting iteration number: 522000
# Starting iteration number: 524000
# Starting iteration number: 526000
# Starting iteration number: 528000
# Starting iteration number: 530000
# Starting iteration number: 532000
# Starting iteration number: 534000
# Starting iteration number: 536000
# Starting iteration number: 538000
# Starting iteration number: 540000
# Starting iteration number: 542000
# Starting iteration number: 544000
# Starting iteration number: 546000
# Starting iteration number: 548000
# Starting iteration number: 550000
# Starting iteration number: 552000
# Starting iteration number: 554000
# Starting iteration number: 556000
# Starting iteration number: 558000
# Starting iteration number: 560000
# Starting iteration number: 562000
# Starting iteration number: 564000
# Starting iteration number: 566000
# Starting iteration number: 568000
# Starting iteration number: 570000
# Starting iteration number: 572000
# Starting iteration number: 574000
# Starting iteration number: 576000
# Starting iteration number: 578000
# Starting iteration number: 580000
# Starting iteration number: 582000
# Starting iteration number: 584000
# Starting iteration number: 586000
# Starting iteration number: 588000
# Starting iteration number: 590000
# Starting iteration number: 592000
# Starting iteration number: 594000
# Starting iteration number: 596000
# Starting iteration number: 598000
# Starting iteration number: 600000
# Predictions:  [[ 0.11081576]
#  [ 0.17373991]
#  [ 0.16127348]
#  ...,
#  [ 0.22531152]
#  [ 0.22048235]
#  [ 0.2856555 ]]
# Actual:  [[ 0.00883905]
#  [ 0.28025015]
#  [ 0.02426649]
#  ...,
#  [ 0.30789906]
#  [ 0.16579075]
#  [ 0.20470108]]
# Minibatch Loss=0.030179
# Starting iteration number: 602000
# Starting iteration number: 604000
# Starting iteration number: 606000
# Starting iteration number: 608000
# Starting iteration number: 610000
# Starting iteration number: 612000
# Starting iteration number: 614000
# Starting iteration number: 616000
# Starting iteration number: 618000
# Starting iteration number: 620000
# Starting iteration number: 622000
# Starting iteration number: 624000
# Starting iteration number: 626000
# Starting iteration number: 628000
# Starting iteration number: 630000
# Starting iteration number: 632000
# Starting iteration number: 634000
# Starting iteration number: 636000
# Starting iteration number: 638000
# Starting iteration number: 640000
# Starting iteration number: 642000
# Starting iteration number: 644000
# Starting iteration number: 646000
# Starting iteration number: 648000
# Starting iteration number: 650000
# Starting iteration number: 652000
# Starting iteration number: 654000
# Starting iteration number: 656000
# Starting iteration number: 658000
# Starting iteration number: 660000
# Starting iteration number: 662000
# Starting iteration number: 664000
# Starting iteration number: 666000
# Starting iteration number: 668000
# Starting iteration number: 670000
# Starting iteration number: 672000
# Starting iteration number: 674000
# Starting iteration number: 676000
# Starting iteration number: 678000
# Starting iteration number: 680000
# Starting iteration number: 682000
# Starting iteration number: 684000
# Starting iteration number: 686000
# Starting iteration number: 688000
# Starting iteration number: 690000
# Starting iteration number: 692000
# Starting iteration number: 694000
# Starting iteration number: 696000
# Starting iteration number: 698000
# Starting iteration number: 700000
# Starting iteration number: 702000
# Starting iteration number: 704000
# Starting iteration number: 706000
# Starting iteration number: 708000
# Starting iteration number: 710000
# Starting iteration number: 712000
# Starting iteration number: 714000
# Starting iteration number: 716000
# Starting iteration number: 718000
# Starting iteration number: 720000
# Starting iteration number: 722000
# Starting iteration number: 724000
# Starting iteration number: 726000
# Starting iteration number: 728000
# Starting iteration number: 730000
# Starting iteration number: 732000
# Starting iteration number: 734000
# Starting iteration number: 736000
# Starting iteration number: 738000
# Starting iteration number: 740000
# Starting iteration number: 742000
# Starting iteration number: 744000
# Starting iteration number: 746000
# Starting iteration number: 748000
# Starting iteration number: 750000
# Starting iteration number: 752000
# Starting iteration number: 754000
# Starting iteration number: 756000
# Starting iteration number: 758000
# Starting iteration number: 760000
# Starting iteration number: 762000
# Starting iteration number: 764000
# Starting iteration number: 766000
# Starting iteration number: 768000
# Starting iteration number: 770000
# Starting iteration number: 772000
# Starting iteration number: 774000
# Starting iteration number: 776000
# Starting iteration number: 778000
# Starting iteration number: 780000
# Starting iteration number: 782000
# Starting iteration number: 784000
# Starting iteration number: 786000
# Starting iteration number: 788000
# Starting iteration number: 790000
# Starting iteration number: 792000
# Starting iteration number: 794000
# Starting iteration number: 796000
# Starting iteration number: 798000
# Starting iteration number: 800000
# Predictions:  [[ 0.31203413]
#  [ 0.22675848]
#  [ 0.21698904]
#  ...,
#  [ 0.25522804]
#  [ 0.1781826 ]
#  [ 0.23681021]]
# Actual:  [[ 0.12782571]
#  [ 0.10260211]
#  [ 0.12169558]
#  ...,
#  [ 0.27777806]
#  [ 0.73084349]
#  [ 0.02035209]]
# Minibatch Loss=0.028999
# Starting iteration number: 802000
# Starting iteration number: 804000
# Starting iteration number: 806000
# Starting iteration number: 808000
# Starting iteration number: 810000
# Starting iteration number: 812000
# Starting iteration number: 814000
# Starting iteration number: 816000
# Starting iteration number: 818000
# Starting iteration number: 820000
# Starting iteration number: 822000
# Starting iteration number: 824000
# Starting iteration number: 826000
# Starting iteration number: 828000
# Starting iteration number: 830000
# Starting iteration number: 832000
# Starting iteration number: 834000
# Starting iteration number: 836000
# Starting iteration number: 838000
# Starting iteration number: 840000
# Starting iteration number: 842000
# Starting iteration number: 844000
# Starting iteration number: 846000
# Starting iteration number: 848000
# Starting iteration number: 850000
# Starting iteration number: 852000
# Starting iteration number: 854000
# Starting iteration number: 856000
# Starting iteration number: 858000
# Starting iteration number: 860000
# Starting iteration number: 862000
# Starting iteration number: 864000
# Starting iteration number: 866000
# Starting iteration number: 868000
# Starting iteration number: 870000
# Starting iteration number: 872000
# Starting iteration number: 874000
# Starting iteration number: 876000
# Starting iteration number: 878000
# Starting iteration number: 880000
# Starting iteration number: 882000
# Starting iteration number: 884000
# Starting iteration number: 886000
# Starting iteration number: 888000
# Starting iteration number: 890000
# Starting iteration number: 892000
# Starting iteration number: 894000
# Starting iteration number: 896000
# Starting iteration number: 898000
# Starting iteration number: 900000
# Starting iteration number: 902000
# Starting iteration number: 904000
# Starting iteration number: 906000
# Starting iteration number: 908000
# Starting iteration number: 910000
# Starting iteration number: 912000
# Starting iteration number: 914000
# Starting iteration number: 916000
# Starting iteration number: 918000
# Starting iteration number: 920000
# Starting iteration number: 922000
# Starting iteration number: 924000
# Starting iteration number: 926000
# Starting iteration number: 928000
# Starting iteration number: 930000
# Starting iteration number: 932000
# Starting iteration number: 934000
# Starting iteration number: 936000
# Starting iteration number: 938000
# Starting iteration number: 940000
# Starting iteration number: 942000
# Starting iteration number: 944000
# Starting iteration number: 946000
# Starting iteration number: 948000
# Starting iteration number: 950000
# Starting iteration number: 952000
# Starting iteration number: 954000
# Starting iteration number: 956000
# Starting iteration number: 958000
# Starting iteration number: 960000
# Starting iteration number: 962000
# Starting iteration number: 964000
# Starting iteration number: 966000
# Starting iteration number: 968000
# Starting iteration number: 970000
# Starting iteration number: 972000
# Starting iteration number: 974000
# Starting iteration number: 976000
# Starting iteration number: 978000
# Starting iteration number: 980000
# Starting iteration number: 982000
# Starting iteration number: 984000
# Starting iteration number: 986000
# Starting iteration number: 988000
