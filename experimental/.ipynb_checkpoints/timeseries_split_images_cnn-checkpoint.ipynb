# %%
import tensorflow as tf
import scipy.misc
import numpy as np
import random
import matplotlib.pyplot as plt
import glob, os

# %matplotlib inline

# %%
def shuffle(X, Y):
    indices = np.arange(X.shape[0])
    random.shuffle(indices)
    X = X[indices]
    Y = Y[indices]
    return X, Y

# %%
all_labels = []
all_labels += glob.glob("./timeseries_data/train_data/reshaped/*.npy")
all_labels += glob.glob("./timeseries_data/val_data/reshaped/*.npy")
all_labels += glob.glob("./timeseries_data/test_data/reshaped/*.npy")
y = np.array([np.load(l) for l in all_labels])

max_dr = np.max(y)
min_dr = np.min(y)

print(max_dr)
print(min_dr)
# Out:
# 1.0
# 1.21763455475e-17

# %%
class Data:
    def __init__(self, imageDir='./timeseries_data/train_data/reshaped/', 
                 labelDir='./timeseries_data/train_data/reshaped/', num_examples=1000):
        image_list = []
        for i in range(num_examples):
            for j in range(10):
                image_list.append(imageDir + 'image' + str(i) + '-' + str(j) + '.png')
        x = []
        for fname in image_list:
            for img in process_image(fname):
                x.append(img)
        x = np.array(x)
        
        label_list = []
        for i in range(num_examples):
            for _ in range(10):
                label_list.append(labelDir + 'drain_rate' + str(i) + '.npy')
        y = np.array([])
        for l in label_list:
            y = np.concatenate((y, np.load(l)))
        y = np.reshape(y, (y.shape[0], 1))
        self.x, self.y = x, y
        
    def next_batch(self, batch_size):
        self.x, self.y = shuffle(self.x, self.y)
        for i in range(0, self.x.shape[0], batch_size):
#             yield self.x[i], self.y[i]
            yield self.x[i:i+batch_size], self.y[i:i+batch_size]
    
    def next_batch_no_shuffle(self, batch_size):
        for i in range(0, self.x.shape[0], batch_size):
#             yield self.x[i], self.y[i]
            yield self.x[i:i+batch_size], self.y[i:i+batch_size]
            
        
def process_image(fname):
    img = scipy.misc.imread(fname, mode='RGB')
    cropped = img[30:430, 10:410, :]

    img_height = 20
    img_width = 40
    
    images = []

    for y in range(20, 0, -1):
        for x in range(10):
            images.append(cropped[(y - 1) * img_height: y * img_height, x * img_width:(x + 1) * img_width, :])

    images = np.array(images)
    return images
    
            
data = Data(num_examples = 10)
batch_generator = data.next_batch_no_shuffle(10000)
a, b = next(batch_generator)
print(a.shape)
print(b.shape)

test_idx = 0
plt.imshow(a[test_idx])
print(b[test_idx])
# Out:
# (10000, 20, 40, 3)
# (10000, 1)
# [ 0.50905213]

# %%
test_idx = 1800
plt.imshow(a[test_idx])
print(b[test_idx])
# Out:
# [ 0.50905213]

# %%
in_height = 20
in_width = 40

learning_rate = 0.001
training_iters = 10000000
batch_size = 10 * 200 * 5
display_step = 10
save_interval = 5 # number of batches per save

n_input = in_height*in_width
n_outputs = 1
dropout = 0.75 # Dropout, probability to keep units


x = tf.placeholder(tf.float32, [None, in_height, in_width, 3], name='x_input')
y = tf.placeholder(tf.float32, [None, n_outputs], name='y_output')
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)


def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)

def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')

def conv_net(x, weights, biases, dropout):
    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['w_out']), biases['b_out'])
    return fc1, out

sd = 0.01

# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 3, 32], stddev=sd)),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64], stddev=sd)),
    # fully connected, (320/8)*(320/4)*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([10*5*64, 1024], stddev=sd)),
    # 1024 inputs, 10 outputs (class prediction)
    'w_out': tf.Variable(tf.random_normal([1024, n_outputs], stddev=sd))
}

biases = {
    'bc1': tf.Variable(tf.zeros([32])),
    'bc2': tf.Variable(tf.zeros([64])),
    'bd1': tf.Variable(tf.zeros([1024])),
    'b_out': tf.Variable(tf.zeros([n_outputs]))
}

fc1, pred = conv_net(x, weights, biases, keep_prob)

cost = tf.reduce_mean(tf.square(tf.subtract(pred, y)))

optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

init = tf.global_variables_initializer()

combined = {}
combined.update(weights)
combined.update(biases)
saver = tf.train.Saver(combined)

# %%
with tf.Session() as sess:
    print("Initialized session")
    data = Data(imageDir='./timeseries_data/train_data/reshaped/', 
                labelDir='./timeseries_data/train_data/reshaped/', num_examples=1000)
    newbatch = data.next_batch(batch_size)
    sess.run(init)

    print("Initialized run")
    
    # Keep training until reach max iterations
    for step in range(0, training_iters, batch_size):     
        print("Starting iteration number: {0}".format(step))
        try:
            batch_x, batch_y = next(newbatch)
        except StopIteration:
            newbatch = data.next_batch(batch_size)
            batch_x, batch_y = next(newbatch)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y, keep_prob: dropout})
#         loss = sess.run(cost, feed_dict={x: batch_x, y: batch_y, keep_prob: 1.})
        if step % 1000000 == 0:
            print("Predictions: ", sess.run(pred, feed_dict={x: batch_x, keep_prob: 1.}))
            print("Actual: ", batch_y)
            fc, loss = sess.run([fc1, cost], feed_dict={x: batch_x, y: batch_y, keep_prob: 1.})
            print("Minibatch Loss={:.6f}".format(loss))
               
    print("Done training!")

    save_path = saver.save(sess, "./rcnn/cnn/cnn.ckpt")
    print("Saved model.")
    
    train_data = Data(imageDir='./timeseries_data/train_data/reshaped/', 
                      labelDir='./timeseries_data/train_data/reshaped/', num_examples=1000)
    newbatch = train_data.next_batch_no_shuffle(200 * 10)
    
    feat_file = "./rcnn/features/features{0}-{1}-{2}.npy"
    
    for i in range(1000):
        batch_x, batch_y = next(newbatch)
        fc, loss = sess.run([fc1, cost], feed_dict={x: batch_x, y: batch_y, keep_prob: 1.})
        features = np.array(fc)
        for j in range(2000):
            plant_num = j % 200
            seq_no = int(j / 200)
            np.save(feat_file.format(i, plant_num, seq_no), features[j])

#     test_data = Data(imageDir='./timeseries_data/test_data/reshaped/', 
#                      labelDir='./timeseries_data/test_data/reshaped/',
#                      num_examples=200)
#     test_batch = test_data.next_batch(200*200*10)
    
#     test_x, test_y = next(test_batch)
    
#     predictions = sess.run(pred, feed_dict={x: test_x, keep_prob: 1.})
    
#     differences = predictions - test_y 
#     print("Average Difference:", np.mean(np.absolute(differences)))
# Out:
# Initialized session
# Initialized run
# Starting iteration number: 0
# Predictions:  [[ 25.28849411]
#  [ 23.36221695]
#  [ 24.30368996]
#  ...,
#  [ 23.40069962]
#  [ 23.41304779]
#  [ 23.32067108]]
# Actual:  [[ 0.01516548]
#  [ 0.12026586]
#  [ 0.19355315]
#  ...,
#  [ 0.14426308]
#  [ 0.28083585]
#  [ 0.04803898]]
# Minibatch Loss=595.351318
# Starting iteration number: 10000
# Starting iteration number: 20000
# Starting iteration number: 30000
# Starting iteration number: 40000
# Starting iteration number: 50000
# Starting iteration number: 60000
# Starting iteration number: 70000
# Starting iteration number: 80000
# Starting iteration number: 90000
# Starting iteration number: 100000
# Starting iteration number: 110000
# Starting iteration number: 120000
# Starting iteration number: 130000
# Starting iteration number: 140000
# Starting iteration number: 150000
# Starting iteration number: 160000
# Starting iteration number: 170000
# Starting iteration number: 180000
# ...
